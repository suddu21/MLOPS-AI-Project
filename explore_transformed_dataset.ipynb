# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")
# %matplotlib inline

# %%
# Load the transformed dataset
# Update the path to match where your transformed_data.csv is saved (e.g., /mnt/c/Users/YourUser/data/transformed_data.csv)
data_path = 'creditcard.csv'
df = pd.read_csv(data_path)

# Display the first few rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Basic statistics of the dataset
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Check the shape of the dataset (rows, columns)
print(f"Dataset shape: {df.shape}")

# Check for missing values
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Dataset shape: (284807, 31)
#
# Missing values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Count of Class 0 (legitimate) vs Class 1 (fraud)
class_counts = df['Class'].value_counts()
print("\nClass distribution:\n", class_counts)

# Visualize the class distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class Distribution (0: Legitimate, 1: Fraud)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
# Out:
# Class distribution:
#  Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Correlation matrix of features (optional, for deeper exploration)
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt='.2f')
plt.title('Correlation Matrix of Features')
plt.show()

# %%
# Box plot of Amount by Class (to see distribution differences)
plt.figure(figsize=(8, 6))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title('Amount Distribution by Class')
plt.xlabel('Class (0: Legitimate, 1: Fraud)')
plt.ylabel('Amount')
plt.show()

# %%
import pandas as pd

# Load the CSV files
test_data = pd.read_csv('test_data.csv')
transformed_data = pd.read_csv('transformed_data.csv')

# Optional: Round floats to 6 decimal places to avoid tiny precision issues
#test_data = test_data.round(6)
#transformed_data = transformed_data.round(6)

# Check if columns match (very important)
if not test_data.columns.equals(transformed_data.columns):
    raise ValueError("Columns of the two files do not match!")

# Merge on all columns to find common rows
common_rows = pd.merge(test_data, transformed_data, how='inner')

if not common_rows.empty:
    print(f"Found {len(common_rows)} common rows!")
    # Optionally, save common rows to a new CSV
    common_rows.to_csv('common_rows.csv', index=False)
else:
    print("No common rows found.")
# Out:
# No common rows found.
